# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.parallel
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data
from torch.autograd import Variable
import scipy

# from sklearn import cross_validation as cv
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


import math

# %%
from surprise import KNNBaseline, KNNBasic, Reader, Dataset, SVD,accuracy
from surprise.model_selection import KFold

# %%
train_df = pd.read_csv('./dataset/cleaned_train_2.csv', 
                 header = 0, 
                 names = ['user', 'movie','rating'], 
                 usecols = [0,1,2])

test_df = pd.read_csv('./dataset/cleaned_test_2.csv', 
                 header = 0, 
                 names = ['user', 'movie','rating'], 
                 usecols = [0,1,2])
reader = Reader()

# %%
knn_base = KNNBasic()
knn_base.fit(train_set)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
train_set = Dataset.load_from_df(train_df[['user','movie','rating']][:167117],reader).build_full_trainset()

# %%
test_set = train_set.build_anti_testset()
pred = knn_base.test(test_set)

# %%
accuracy.rmse(pred)
accuracy.mse(pred)
# Out:
# RMSE: 0.7137
# MSE: 0.5094
# 0.509400066739161

# %%
svd = SVD()
svd.fit(train_set)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-58aa054b73c1> in <module>
#       1 svd = SVD()
# ----> 2 svd.train(train_set)
#
# AttributeError: 'SVD' object has no attribute 'train'

# %%
svdpred = svd.test(test_set)

# %%
accuracy.rmse(svdpred)
accuracy.mse(svdpred)
# Out:
# RMSE: 0.6176
# MSE: 0.3815
# 0.3814511886397808

# %%
svdpred
# Out:
# [Prediction(uid=1488844, iid=28, r_ui=3.052280737447417, est=3.8653168387813173, details={'was_impossible': False}),
#  Prediction(uid=1488844, iid=256, r_ui=3.052280737447417, est=2.7986184187487817, details={'was_impossible': False}),
#  Prediction(uid=1488844, iid=290, r_ui=3.052280737447417, est=3.633009817475442, details={'was_impossible': False}),
#  Prediction(uid=1488844, iid=362, r_ui=3.052280737447417, est=2.329657629167766, details={'was_impossible': False}),
#  Prediction(uid=1488844, iid=401, r_ui=3.052280737447417, est=2.9936792956893936, details={'was_impossible': False}),
#  Prediction(uid=1488844, iid=442, r_ui=3.052280737447417, est=3.3635835757743293, details={'was_impossible': False}),
#  Prediction(uid=1488844, iid=531, r_ui=3.052280737447417, est=2.7659606243418016, details={'was_impossible': False}),
#  Prediction(uid=1488844, iid=694, r_ui=3.052280737447417, est=3.6420347707701577, details={'was_impossible': False}),
# ...

# %%
# knn = KNeighborsClassifier(n_neighbors=10)

# %%
# data = Dataset.load_from_folds([("./dataset/cleaned_train_2.csv","dataset/cleaned_test_2.csv")],reader).
# kf =  KFold(n_splits=3)

# %%
# npdata = np.loadtxt("./dataset/sprase_train_2.txt") 
# print("shape: ",npdata.shape)

# %%
# Out:
# MSE: 0.5094
# 0.509400066739161
